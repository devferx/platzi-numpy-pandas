# %% [markdown]
# <a href="https://colab.research.google.com/github/devferx/platzi-numpy-pandas/blob/main/16_funciones_principales_de_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funciones principales de Pandas
# Hay ciertas funciones que son muy importantes y que siempre estaremos usando a la hora de hacer análisis de datos, para mayor facilidad y comprensión del DataFrame.

# %%
import pandas as pd

# %%
df_books = pd.read_csv('https://raw.githubusercontent.com/devferx/platzi-numpy-pandas/main/11_leer_archivos_csv_json_pandas/bestsellers-with-categories.csv')

# %% [markdown]
# Mostrar las primeras dos líneas de registro

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# Mostrar los diferentes datos que contiene el DataFrame

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %% [markdown]
# Obtener diferentes datos estadísticos de las columnas numéricas.

# %%
df_books.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# Mostrar los últimos 5 registros del DataFrame

# %%
df_books.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %% [markdown]
# Obtener el uso de la memoria de cada columna

# %%
df_books.memory_usage(deep=True)
# Out:
# Index            128
# Name           59737
# Author         39078
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          36440
# dtype: int64

# %% [markdown]
# Obtener cuantos datos tenemos de algo en específico

# %%
df_books['Author'].value_counts()
# ---> Muestra cuantos datos hay de cada autor
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: Author, Length: 248, dtype: int64

# %% [markdown]
# **Manejando Datos duplicados**

# %%
df_books.iloc[0]
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                              JJ Smith
# User Rating                              4.7
# Reviews                                17350
# Price                                      8
# Year                                    2016
# Genre                            Non Fiction
# Name: 0, dtype: object

# %%
df_books.append(df_books.iloc[0])
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# Eliminar registros duplicados

# %%
df_books.drop_duplicates()
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# Si se desea mantener el ultimo duplicado podemos mandar el parametro keep

# %%
df_books.drop_duplicates(keep='last')
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# Ordenar los registros según valores de la columna (orden ascendente)

# %%
df_books.sort_values('Year')
# Out:
#                                                   Name            Author  \
# 177                                      I, Alex Cross   James Patterson
# 131  Glenn Beck's Common Sense: The Case Against an...        Glenn Beck
# 417                                   The Last Lecture      Randy Pausch
# 241                       New Moon (The Twilight Saga)   Stephenie Meyer
# 72       Diary of a Wimpy Kid: The Last Straw (Book 3)       Jeff Kinney
# ..                                                 ...               ...
# 150                                               Guts  Raina Telgemeier
# 466  The Subtle Art of Not Giving a F*ck: A Counter...       Mark Manson
# 462                                 The Silent Patient  Alex Michaelides
# 130  Girl, Wash Your Face: Stop Believing the Lies ...     Rachel Hollis
# 549  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
df_books.sort_values('Year', ascending=False)
# Out:
#                                                   Name                 Author  \
# 549  You Are a Badass: How to Stop Doubting Your Gr...            Jen Sincero
# 294  School Zone - Big Preschool Workbook - Ages 4 ...            School Zone
# 489                   The Wonderful Things You Will Be  Emily Winfield Martin
# 263    P is for Potty! (Sesame Street) (Lift-the-Flap)        Naomi Kleinberg
# 130  Girl, Wash Your Face: Stop Believing the Lies ...          Rachel Hollis
# ..                                                 ...                    ...
# 418  The Last Olympian (Percy Jackson and the Olymp...           Rick Riordan
# 38           Breaking Dawn (The Twilight Saga, Book 4)        Stephenie Meyer
# 92   Eat This, Not That! Thousands of Simple Food S...        David Zinczenko
# 139  Good to Great: Why Some Companies Make the Lea...            Jim Collins
# 299                                  Sookie Stackhouse       Charlaine Harris
#
# ...

# %% [markdown]
# Agrupar y contar

# %%
df_books.groupby('Genre').size()
# Out:
# Genre
# Fiction        240
# Non Fiction    310
# dtype: int64

# %% [markdown]
# ### Recursos
# - [10 minutes to pandas](https://pandas.pydata.org/docs/user_guide/10min.html)
