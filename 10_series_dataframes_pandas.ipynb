# %% [markdown]
# # Pandas
# Pandas es una librería de Python especializada en el manejo y análisis de estructuras de datos. El nombre viene de “Panel data”.
#
# - Velocidad
# - Poco código
# - Múltiples formatos de archivos
# - Alineación inteligente

# %%
import pandas as pd

# %% [markdown]
# ## Pandas Series
# Es muy parecido a un array de una dimensión (o vector) de NumPy
#
# - Arreglo unidimensional indexado
# - Búsqueda por índice
# - Slicing
# - Operaciones aritméticas
# - Distintos tipos de datos

# %%
pd.Series(['Navas', 'Mbappe', 'Neymar', 'Messi'])
# Out:
# 0     Navas
# 1    Mbappe
# 2    Neymar
# 3     Messi
# dtype: object

# %% [markdown]
# Definiendo una lista con **índices específicos**

# %%
psg_players = pd.Series(
    ['Navas', 'Mbappe', 'Neymar', 'Messi'],
    index=[1, 7, 10, 30]
)
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players_dict = {1: 'Navas', 7: 'Mbappe', 10: 'Neymar', 30: 'Messi'}
pd.Series(psg_players_dict)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[7]
# Out:
# 'Mbappe'

# %% [markdown]
# Búsqueda mediante **Slicing**

# %%
psg_players = pd.Series(['Navas', 'Mbappe', 'Neymar', 'Messi'])
psg_players[0:3]
# Out:
# 0     Navas
# 1    Mbappe
# 2    Neymar
# dtype: object

# %% [markdown]
# ## Pandas DataFrame
# Muy parecido a las estructuras matriciales trabajadas con NumPy.
#
# - Estructura principal
# - Arreglo de dos dimensiones
# - Búsqueda por índice (columnas o filas)
# - Slicing
# - Operaciones aritméticas
# - Distintos tipos de datos
# - Tamaño variable

# %%
psg_players_data = {
    'Jugador': ['Navas', 'Mbappe', 'Neymar', 'Messi'],
    'Altura': [183.0, 170.0, 170.0, 163.0],
    'Goles': [2, 200, 150, 500]
 }

# %%
df_players = pd.DataFrame(psg_players_data, index=[1,7,10,30])

# %% [markdown]
# Búsqueda por índices. **Columnas**

# %%
df_players.columns
# Out:
# Index(['Jugador', 'Altura', 'Goles'], dtype='object')

# %% [markdown]
# Búsqueda por **índice**.

# %%
df_players.index
# Out:
# Int64Index([1, 7, 10, 30], dtype='int64')

# %% [markdown]
# ### Reto
#
# Usa este DataFrame de Granada FC
#
# Crea tus propios DataFrames, con los índices que quieras y comparte tus resultados.
#
# ```
# 'Jugador':['Luis Suarez','Jorge Molina', 'Antonio Puertas', 'German Sanchez', 'Luis Milla', 'Luis Manuel Arantes Maximiano']
#
# 'Posicion':['Delantero', 'Delantero', 'Centrocampista', 'Defensa', 'Centrocampista', 'Portero']
#
# 'Numero':[9, 23, 10, 6, 5, 1]
#
# 'Altura':[185.0, 187.0, 185.0, 187.0, 175.0, 190.0]
#
# 'Goles':[7, 7, 5, 2, 2, 0]
# ```

# %%
granada_fc_data = {
    'Jugador':['Luis Suarez','Jorge Molina', 'Antonio Puertas', 'German Sanchez', 'Luis Milla', 'Luis Manuel Arantes Maximiano'],
    'Posicion':['Delantero', 'Delantero', 'Centrocampista', 'Defensa', 'Centrocampista', 'Portero'],
    'Altura':[185.0, 187.0, 185.0, 187.0, 175.0, 190.0],
    'Goles':[7, 7, 5, 2, 2, 0],
    'Numero':[9, 23, 10, 6, 5, 1]
}

# %%
granada_fc_df = pd.DataFrame(granada_fc_data)
granada_fc_df
# Out:
#                          Jugador        Posicion  Altura  Goles  Numero
# 0                    Luis Suarez       Delantero   185.0      7       9
# 1                   Jorge Molina       Delantero   187.0      7      23
# 2                Antonio Puertas  Centrocampista   185.0      5      10
# 3                 German Sanchez         Defensa   187.0      2       6
# 4                     Luis Milla  Centrocampista   175.0      2       5
# 5  Luis Manuel Arantes Maximiano         Portero   190.0      0       1
