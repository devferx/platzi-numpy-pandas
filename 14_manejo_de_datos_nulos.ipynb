# %% [markdown]
# <a href="https://colab.research.google.com/github/devferx/platzi-numpy-pandas/blob/main/14_manejo_de_datos_nulos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Manejo de datos nulos
#
# Los datos nulos son dolores de cabeza para este mundo de la ciencia de datos y se van a encontrar mucho en nuestros DataFrames

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Creamos un DataFrame con algunos valores nulos

# %%
my_dict = {
    'Col1': [1,2,3,np.nan],
    'Col2': [4, np.nan,6,7],
    'Col3': ['a', 'b', 'c', None]
 }

# %%
df = pd.DataFrame(my_dict)

# %%
df
# Out:
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   NaN     b
# 2   3.0   6.0     c
# 3   NaN   7.0  None

# %% [markdown]
# Identificar valores nulos en un DataFrame

# %%
df.isnull()
# Out:
#     Col1   Col2   Col3
# 0  False  False  False
# 1  False   True  False
# 2  False  False  False
# 3   True  False   True

# %% [markdown]
# Identificar valores nulos con un valor numérico

# %%
df.isnull() * 1
# Out:
#    Col1  Col2  Col3
# 0     0     0     0
# 1     0     1     0
# 2     0     0     0
# 3     1     0     1

# %% [markdown]
# Sustituir los valores nulos por una cadena

# %%
df.fillna('Missing')
# Out:
#       Col1     Col2     Col3
# 0      1.0      4.0        a
# 1      2.0  Missing        b
# 2      3.0      6.0        c
# 3  Missing      7.0  Missing

# %% [markdown]
# Sustituir valores nulos por una medida estadística realizada con los valores de las columnas

# %%
df.fillna(df.mean())
# Out:
# <ipython-input-9-a2478f315f9e>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#    Col1      Col2  Col3
# 0   1.0  4.000000     a
# 1   2.0  5.666667     b
# 2   3.0  6.000000     c
# 3   2.0  7.000000  None

# %% [markdown]
# Sustituir valores nulos por valores de **interpolación**

# %%
df.interpolate()
# Out:
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   5.0     b
# 2   3.0   6.0     c
# 3   3.0   7.0  None

# %% [markdown]
# Eliminar valores nulos

# %%
df.dropna()
# Out:
#    Col1  Col2 Col3
# 0   1.0   4.0    a
# 2   3.0   6.0    c

# %% [markdown]
# ### Recursos
# - [pandas.isnull](https://pandas.pydata.org/docs/reference/api/pandas.isnull.html)
# - [pandas.DataFrame.fillna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html)
# - [pandas.DataFrame.dropna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)
